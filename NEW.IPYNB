# %%
import pandas as pd

# %%
data=pd.read_csv('data_clean.csv')

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1    710  GoldenEye  James Bond must unmask the mysterious head of ...
# 2  10634     Friday  Craig and Smokey are two guys in Los Angeles h...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 2  [{'cast_id': 1, 'character': 'Craig Jones', 'c...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe426ec3a36847f801e14b', 'de...
# 2  [{'credit_id': '52fe43999251416c75016ad5', 'de...
#
# ...

# %%
import ast

# %%
def genres(col):
    l=[]
    for i in ast.literal_eval(col):
        l.append(i['name']) 
    return l

# %%
data['genres']=data['genres'].apply(genres)

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1    710  GoldenEye  James Bond must unmask the mysterious head of ...
# 2  10634     Friday  Craig and Smokey are two guys in Los Angeles h...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 2  [{'cast_id': 1, 'character': 'Craig Jones', 'c...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe426ec3a36847f801e14b', 'de...
# 2  [{'credit_id': '52fe43999251416c75016ad5', 'de...
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# ...

# %%
data['overview']=data['overview'].apply(lambda x:x.split())

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 2  [{'cast_id': 1, 'character': 'Craig Jones', 'c...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe426ec3a36847f801e14b', 'de...
# 2  [{'credit_id': '52fe43999251416c75016ad5', 'de...
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# ...

# %%
print(data['genres'].iloc[0])
print(type(data['genres'].iloc[0]))
# Out:
# ['Animation', 'Comedy', 'Family']
# <class 'list'>

# %%
data['genres'] = data['genres'].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [PierceBrosnan, SeanBean, IzabellaScorupco, Fa...
# 2  [IceCube, ChrisTucker, NiaLong, TomListerJr., ...
#
#                                                 crew  \
# 0  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
# 1  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
# 2  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# ...

# %%
print(data['cast'].iloc[0])
print(type(data['cast'].iloc[0]))
# Out:
# ['TomHanks', 'TimAllen', 'DonRickles', 'JimVarney', 'WallaceShawn', 'JohnRatzenberger', 'AnniePotts', 'JohnMorris', 'ErikvonDetten', 'LaurieMetcalf', 'R.LeeErmey', 'SarahFreeman', 'PennJillette']
# <class 'list'>

# %%
data['cast'] = data['cast'].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
print(data['crew'].iloc[0])
print(type(data['crew'].iloc[0]))
# Out:
# ['[', '{', "'", 'c', 'r', 'e', 'd', 'i', 't', '_', 'i', 'd', "'", ':', '', "'", '5', '2', 'f', 'e', '4', '2', '8', '4', 'c', '3', 'a', '3', '6', '8', '4', '7', 'f', '8', '0', '2', '4', 'f', '4', '9', "'", ',', '', "'", 'd', 'e', 'p', 'a', 'r', 't', 'm', 'e', 'n', 't', "'", ':', '', "'", 'D', 'i', 'r', 'e', 'c', 't', 'i', 'n', 'g', "'", ',', '', "'", 'g', 'e', 'n', 'd', 'e', 'r', "'", ':', '', '2', ',', '', "'", 'i', 'd', "'", ':', '', '7', '8', '7', '9', ',', '', "'", 'j', 'o', 'b', "'", ':', '', "'", 'D', 'i', 'r', 'e', 'c', 't', 'o', 'r', "'", ',', '', "'", 'n', 'a', 'm', 'e', "'", ':', '', "'", 'J', 'o', 'h', 'n', '', 'L', 'a', 's', 's', 'e', 't', 'e', 'r', "'", ',', '', "'", 'p', 'r', 'o', 'f', 'i', 'l', 'e', '_', 'p', 'a', 't', 'h', "'", ':', '', "'", '/', '7', 'E', 'd', 'q', 'i', 'N', 'b', 'r', '4', 'F', 'R', 'j', 'I', 'h', 'K', 'H', 'y', 'P', 'P', 'd', 'F', 'f', 'E', 'E', 'E', 'F', 'G', '.', 'j', 'p', 'g', "'", '}', ',', '', '{', "'", 'c', 'r', 'e', 'd', 'i', 't', '_', 'i', 'd
# ...

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast  \
# 0  [TomHanks, TimAllen, DonRickles, JimVarney, Wa...
# 1  [PierceBrosnan, SeanBean, IzabellaScorupco, Fa...
# 2  [IceCube, ChrisTucker, NiaLong, TomListerJr., ...
#
#                                                 crew  \
# 0  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
# 1  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
# 2  [[, {, ', c, r, e, d, i, t, _, i, d, ', :, , '...
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# ...

# %%
def convert(x):
    if isinstance(x, str):
        return ast.literal_eval(x)
    return x

# %%
data['crew'] = data['crew'].apply(convert)

# %%
print(data['crew'].iloc[0])
print(type(data['crew'].iloc[0]))
# Out:
# ['[', '{', "'", 'c', 'r', 'e', 'd', 'i', 't', '_', 'i', 'd', "'", ':', '', "'", '5', '2', 'f', 'e', '4', '2', '8', '4', 'c', '3', 'a', '3', '6', '8', '4', '7', 'f', '8', '0', '2', '4', 'f', '4', '9', "'", ',', '', "'", 'd', 'e', 'p', 'a', 'r', 't', 'm', 'e', 'n', 't', "'", ':', '', "'", 'D', 'i', 'r', 'e', 'c', 't', 'i', 'n', 'g', "'", ',', '', "'", 'g', 'e', 'n', 'd', 'e', 'r', "'", ':', '', '2', ',', '', "'", 'i', 'd', "'", ':', '', '7', '8', '7', '9', ',', '', "'", 'j', 'o', 'b', "'", ':', '', "'", 'D', 'i', 'r', 'e', 'c', 't', 'o', 'r', "'", ',', '', "'", 'n', 'a', 'm', 'e', "'", ':', '', "'", 'J', 'o', 'h', 'n', '', 'L', 'a', 's', 's', 'e', 't', 'e', 'r', "'", ',', '', "'", 'p', 'r', 'o', 'f', 'i', 'l', 'e', '_', 'p', 'a', 't', 'h', "'", ':', '', "'", '/', '7', 'E', 'd', 'q', 'i', 'N', 'b', 'r', '4', 'F', 'R', 'j', 'I', 'h', 'K', 'H', 'y', 'P', 'P', 'd', 'F', 'f', 'E', 'E', 'E', 'F', 'G', '.', 'j', 'p', 'g', "'", '}', ',', '', '{', "'", 'c', 'r', 'e', 'd', 'i', 't', '_', 'i', 'd
# ...

# %%
data=pd.read_csv('data_clean.csv')

# %%
data['crew'] = data['crew'].apply(ast.literal_eval)

# %%
print(type(data['crew'].iloc[0]))
print(type(data['crew'].iloc[0][0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %%
print(data['crew'].iloc[0])
# Out:
# JohnLasseter

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1    710  GoldenEye  James Bond must unmask the mysterious head of ...
# 2  10634     Friday  Craig and Smokey are two guys in Los Angeles h...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                 cast            crew  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...    JohnLasseter
# 1  [{'cast_id': 1, 'character': 'James Bond', 'cr...  MartinCampbell
# 2  [{'cast_id': 1, 'character': 'Craig Jones', 'c...      F.GaryGray
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# ...

# %%
import ast

# %%
def genres(col):
    l=[]
    for i in ast.literal_eval(col):
        l.append(i['name']) 
    return l

# %%
data['genres']=data['genres'].apply(genres)

# %%
data['overview']=data['overview'].apply(lambda x:x.split())

# %%
data['genres'] = data['genres'].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast            crew  \
# 0  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, 4, ,...    JohnLasseter
# 1  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, ,, ,...  MartinCampbell
# 2  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, ,, ,...      F.GaryGray
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html

# %%
data['cast']=data['cast'].dropna()

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres  \
# 0    [Animation, Comedy, Family]
# 1  [Adventure, Action, Thriller]
# 2                       [Comedy]
#
#                                                 cast            crew  \
# 0  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, 4, ,...    JohnLasseter
# 1  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, ,, ,...  MartinCampbell
# 2  [[, {, ', c, a, s, t, _, i, d, ', :, , 1, ,, ,...      F.GaryGray
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html

# %%
data.drop('cast', axis=1, inplace=True)

# %%
data.head(3)
# Out:
#       id      title                                           overview  \
# 0    862  Toy Story  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1    710  GoldenEye  [James, Bond, must, unmask, the, mysterious, h...
# 2  10634     Friday  [Craig, and, Smokey, are, two, guys, in, Los, ...
#
#                           genres            crew  \
# 0    [Animation, Comedy, Family]    JohnLasseter
# 1  [Adventure, Action, Thriller]  MartinCampbell
# 2                       [Comedy]      F.GaryGray
#
#                                         homepage
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html

# %%
data['tags']=data['overview']+data['genres']

# %%
data.drop(['overview', 'genres'], axis=1, inplace=True)

# %%
data.head(3)
# Out:
#       id      title            crew  \
# 0    862  Toy Story    JohnLasseter
# 1    710  GoldenEye  MartinCampbell
# 2  10634     Friday      F.GaryGray
#
#                                         homepage  \
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html
#
#                                                 tags
# 0  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1  [James, Bond, must, unmask, the, mysterious, h...
# 2  [Craig, and, Smokey, are, two, guys, in, Los, ...

# %%
data.head(3)
# Out:
#       id      title            crew  \
# 0    862  Toy Story    JohnLasseter
# 1    710  GoldenEye  MartinCampbell
# 2  10634     Friday      F.GaryGray
#
#                                         homepage  \
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html
#
#                                                 tags
# 0  [Led, by, Woody,, Andy's, toys, live, happily,...
# 1  [James, Bond, must, unmask, the, mysterious, h...
# 2  [Craig, and, Smokey, are, two, guys, in, Los, ...

# %%
data.to_csv('workdata_clean.csv', index=False)

# %%
pip install nltk
# Out:
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 12.3 MB/s  0:00:00
# ...
# Using cached click-8.5.0-py3-none-any.whl (125 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# ...
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [defusedxml]
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()

# %%
def stemmer(text):
    l=[]
    for i in text:
        l.append(ps.stem(i))
    return " ".join(l)

# %%
data['tags']=data['tags'].apply(stemmer)

# %%
data.head(3)
# Out:
#       id      title            crew  \
# 0    862  Toy Story    JohnLasseter
# 1    710  GoldenEye  MartinCampbell
# 2  10634     Friday      F.GaryGray
#
#                                         homepage  \
# 0           http://toystory.disney.com/toy-story
# 1   http://www.mgm.com/view/movie/757/Goldeneye/
# 2  http://www.newline.com/properties/friday.html
#
#                                                 tags
# 0  led by woody, andy' toy live happili in hi roo...
# 1  jame bond must unmask the mysteri head of the ...
# 2  craig and smokey are two guy in lo angel hang ...

# %%
data['tags'][0]
# Out:
# "led by woody, andy' toy live happili in hi room until andy' birthday bring buzz lightyear onto the scene. afraid of lose hi place in andy' heart, woodi plot against buzz. but when circumst separ buzz and woodi from their owner, the duo eventu learn to put asid their differences. anim comedi famili"

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_features=5000, stop_words='english')

# %%
vectors=tfidf.fit_transform(data['tags']).toarray()

# %%
print(vectors.shape)
# Out:
# (980, 5000)

# %%
tfidf.get_feature_names_out()[:200]
# Out:
# array(['00', '000', '007', '009', '01', '10', '100', '1000', '108',
#        '10crores', '11', '117', '11th', '12', '12th', '13', '13th', '14',
#        '15', '150', '16', '17', '18', '1923', '1955', '1957', '1969',
#        '1980s', '1983', '1985', '1986', '1988', '1990', '1994', '1996',
#        '1997', '1998', '1999', '20', '200', '2001', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2019', '2028', '21st', '22nd',
#        '23', '24', '25', '250', '26', '30', '300', '35', '3d', '3po',
#        '42', '47', '49', '4th', '50', '501st', '60', '70', '80', '95',
#        'aaron', 'abandon', 'abduct', 'abigail', 'abil', 'abl', 'aboard',
#        'absolut', 'absorb', 'abus', 'academ', 'academi', 'academy',
#        'accept', 'accid', 'accident', 'accompani', 'accomplish', 'accord',
#        'account', 'accus', 'accused', 'acerola', 'achiev', 'acquir',
#        'act', 'action', 'activ', 'activist', 'actor', 'actress', 'actual',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
vectors.shape
# Out:
# (980, 5000)

# %%
similarity[1]
# Out:
# array([0.        , 1.        , 0.        , 0.01619748, 0.        ,
#        0.0139851 , 0.        , 0.01149885, 0.        , 0.        ,
#        0.00624939, 0.01185709, 0.        , 0.02080831, 0.02659045,
#        0.07121102, 0.03248057, 0.        , 0.        , 0.05894962,
#        0.        , 0.        , 0.00848248, 0.01419717, 0.00808744,
#        0.        , 0.04635002, 0.00558465, 0.        , 0.04418906,
#        0.01657941, 0.        , 0.03914397, 0.01267721, 0.0068141 ,
#        0.0132504 , 0.00654793, 0.        , 0.01420878, 0.06313466,
#        0.02000569, 0.07286251, 0.04463423, 0.        , 0.07954542,
#        0.01307018, 0.00789907, 0.00967539, 0.03110239, 0.00692686,
#        0.        , 0.01201672, 0.00679637, 0.0113747 , 0.04675509,
#        0.01648664, 0.00436771, 0.02456523, 0.02196782, 0.12169103,
#        0.01505488, 0.00707295, 0.01310643, 0.08085448, 0.        ,
#        0.00632274, 0.02066035, 0.        , 0.11353456, 0.07706156,
# ...

# %%
def recommend(movie):
    movie_index = data[data["title"] == movie].index[0]

    distances = similarity[movie_index]

    movie_list = sorted(
        list(enumerate(distances)),
        reverse=True,
        key=lambda x: x[1]
    )[1:6]

    for i in movie_list:
        print(data.iloc[i[0]]["title"])
        print("Homepage:", data.iloc[i[0]]["homepage"])

# %%
recommend("Toy Story")
# Out:
# Toy Story 3
# Homepage: http://disney.go.com/toystory/
# Toy Story 2
# Homepage: http://toystory.disney.com/toy-story-2
# Harry Potter and the Philosopher's Stone
# Homepage: http://harrypotter.warnerbros.com/harrypotterandthedeathlyhallows/mainsite/index.html
# Monsters, Inc.
# Homepage: http://movies.disney.com/monsters-inc
# A Close Shave
# Homepage: http://www.wallaceandgromit.com/films/a-close-shave

# %%
recommend("GoldenEye")
# Out:
# Octopussy
# Homepage: http://www.mgm.com/view/movie/1394/Octopussy/
# Licence to Kill
# Homepage: http://www.mgm.com/view/movie/1111/License-to-Kill/
# Live and Let Die
# Homepage: http://www.mgm.com/view/movie/1130/Live-and-Let-Die/
# You Only Live Twice
# Homepage: http://www.mgm.com/view/movie/2347/You-Only-Live-Twice/
# Never Say Never Again
# Homepage: http://www.mgm.com/view/movie/1345/Never-Say-Never-Again/
